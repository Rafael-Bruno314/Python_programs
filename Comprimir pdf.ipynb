# %% [markdown]
# pip install PDFNetPython3

# %% [markdown]
# pip install --upgrade pip

# %%
# Import Libraries
import os
import sys
from PDFNetPython3.PDFNetPython import PDFDoc, Optimizer, SDFDoc, PDFNet

# %%
def get_size_format(b, factor=1024, suffix="B"):
    """
    Scale bytes to its proper byte format
    e.g:
        1253656 => '1.20MB'
        1253656678 => '1.17GB'
    """
    for unit in ["", "K", "M", "G", "T", "P", "E", "Z"]:
        if b < factor:
            return f"{b:.2f}{unit}{suffix}"
        b /= factor
    return f"{b:.2f}Y{suffix}"

# %%
def compress_file(input_file: str, output_file: str):
    """Compress PDF file"""
    if not output_file:
        output_file = input_file
    initial_size = os.path.getsize(input_file)
    try:
        # Initialize the library
        PDFNet.Initialize("demo:1652721067096:7b89dd1603000000008ca8f036d3c1112cd0debd5cca3f78321ecf6f88")
        doc = PDFDoc(input_file)
        # Optimize PDF with the default settings
        doc.InitSecurityHandler()
        # Reduce PDF size by removing redundant information and compressing data streams
        Optimizer.Optimize(doc)
        doc.Save(output_file, SDFDoc.e_linearized)
        doc.Close()
    except Exception as e:
        print("Error compress_file=", e)
        doc.Close()
        return False
    compressed_size = os.path.getsize(output_file)
    ratio = 1 - (compressed_size / initial_size)
    summary = {
        "Input File": input_file, "Initial Size": get_size_format(initial_size),
        #"Output File": output_file, f"Compressed Size": get_size_format(compressed_size),
        "Compression Ratio": "{0:.3%}.".format(ratio)
    }
    # Printing Summary
    print("--------------------- Resumo da compressão ------------------------")
    print("\n".join("{}:{}".format(i, j) for i, j in summary.items()))
    print("-------------------------------------------------------------------")
    print("")
    return True

# %% [markdown]
# if __name__ == "__main__":
#
#     endereco_dos_arquivos = "C:\\Users\\Rafael Bruno\\Documents\\Formação Pedagógica\\PDFs das Disciplinas\\Didática\\Abordagens didáticas na prática docente\\"
#     # Endereço da pasta com os arquivos pdf a serem comprimidos
#
#     # ---------------------------------------------------------------------------------------------
#
#     arquivos = os.listdir(endereco_dos_arquivos)
#
#     for arquivo in arquivos:
#         if(arquivo.endswith('.pdf')):
#             print(arquivo)
#             compress_file(endereco_dos_arquivos + arquivo, endereco_dos_arquivos + arquivo)

# %%
input_folder = "C:\\Users\\Rafael Bruno\\Documents\\Formação Pedagógica\\PDFs das Disciplinas\\"

for root, dirs, files in os.walk(input_folder):
        for file in files:
            if file.endswith(".pdf"):
                pdf_path = os.path.join(root, file)
                #output_path = os.path.join(output_folder, file)

                # Otimiza o arquivo PDF
                #optimize_pdf(pdf_path, output_path)
                compress_file(pdf_path, pdf_path)
                #print(f"Arquivo otimizado: {pdf_path}")

print("Otimização concluída!")
# Out:
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Didática\Abordagens didáticas na prática docente\Abordagens didáticas na prática docente.pdf
# Initial Size:5.20MB
# Compression Ratio:0.000%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Didática\Ação Pedagógica e Transposição Didática\Ação Pedagógica e Transposição Didática.pdf
# Initial Size:5.55MB
# Compression Ratio:29.384%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Didática\Conceito de Didática e Sua Origem\Conceito de Didática e Sua Origem.pdf
# Initial Size:3.90MB
# Compression Ratio:27.019%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Didática\Didática e Uso Das Tecnologias\Didática e Uso Das Tecnologias.pdf
# Initial Size:4.87MB
# Compression Ratio:27.534%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Didática\Os Processos Didáticos e os Desafios da Contemporaneidade\Os Processos Didáticos e os Desafios da Contemporaneidade.pdf
# Initial Size:5.25MB
# Compression Ratio:24.812%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Didática\Tendências Pedagógicas\Tendências Pedagógicas.pdf
# Initial Size:5.83MB
# Compression Ratio:29.349%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Educação Especial\Educação Especial e Inclusiva\Educação Especial e Inclusiva.pdf
# Initial Size:1.97MB
# Compression Ratio:36.929%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Educação Especial\Educação Inclusiva - Deficiência Física ou Motora\Educação inclusiva_ deficiência física ou motora.pdf
# Initial Size:796.44KB
# Compression Ratio:17.624%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Educação Especial\Inclusão de Transtornos Globais do Desenvolvimento na Educação\Inclusão de transtornos mentais na educação.pdf
# Initial Size:2.06MB
# Compression Ratio:20.327%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Educação Especial\Recursos na Educação Especial\Recursos na Educação Especial.pdf
# Initial Size:1.48MB
# Compression Ratio:35.852%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Educação Especial\Teorias Pedagógicas Aplicadas à Deficiência Visual\Teorias pedagógicas aplicadas_ deficiência visual.pdf
# Initial Size:2.57MB
# Compression Ratio:24.469%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Educação Especial\Teorias Pedagógicas Aplicadas à Surdez deficiência Auditiva\TEORIAS PEDAGÓGICAS APLICADAS_ SURDEZ _DEFICIÊNCIA AUDITIVA.pdf
# Initial Size:4.05MB
# Compression Ratio:11.013%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Fund. da Educ. de Jovens e Adultos e Educ. Popular\As Contribuições de Paulo Freire Para a Educação de Jovens e Adultos\A relação teoria e prática na educação em freire.pdf
# Initial Size:236.54KB
# Compression Ratio:40.874%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Fund. da Educ. de Jovens e Adultos e Educ. Popular\As Contribuições de Paulo Freire Para a Educação de Jovens e Adultos\As Contribuições de Paulo Freire Para a Educação de Jovens e Adultos.pdf
# Initial Size:313.76KB
# Compression Ratio:5.153%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Fund. da Educ. de Jovens e Adultos e Educ. Popular\Educação de Jovens e Adultos e a Diversidade\Educação de Jovens e Adultos e a Diversidade.pdf
# Initial Size:11.07MB
# Compression Ratio:31.247%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Fund. da Educ. de Jovens e Adultos e Educ. Popular\Os Desafios da Educação de Jovens e Adultos no Cenário Contemporâneo\Os Desafios da Educação de Jovens e Adultos no Cenário Contemporâneo 01.pdf
# Initial Size:315.00KB
# Compression Ratio:20.654%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Fund. da Educ. de Jovens e Adultos e Educ. Popular\Os Desafios da Educação de Jovens e Adultos no Cenário Contemporâneo\Os Desafios da Educação de Jovens e Adultos.pdf
# Initial Size:183.54KB
# Compression Ratio:17.992%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Fund. da Educ. de Jovens e Adultos e Educ. Popular\Os Novos Rumos da Eja no Brasil a Partir Dos Anos 70\Os Novos Rumos da Eja no Brasil a Partir Dos Anos 70.pdf
# Initial Size:10.22MB
# Compression Ratio:30.095%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Fund. da Educ. de Jovens e Adultos e Educ. Popular\Uma Visão Retrospectiva Sobre a Eja no Brasil\Uma Visão Retrospectiva Sobre a Eja no Brasil.pdf
# Initial Size:7.17MB
# Compression Ratio:33.214%.
# -------------------------------------------------------------------
#
# --------------------- Resumo da compressão ------------------------
# Input File:C:\Users\Rafael Bruno\Documents\Formação Pedagógica\PDFs das Disciplinas\Fundamentos da Educação\Educação Formal e Não Formal\Educação Formal e Não Formal.pdf
# Initial Size:11.78MB
# Compression Ratio:28.180%.
# -------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3756\1626863430.py in ?()
#       7                 #output_path = os.path.join(output_folder, file)
#       8
#       9                 # Otimiza o arquivo PDF
#      10                 #optimize_pdf(pdf_path, output_path)
# ---> 11                 compress_file(pdf_path, pdf_path)
#      12                 #print(f"Arquivo otimizado: {pdf_path}")
#      13
#      14 print("Otimização concluída!")
#
# ~\AppData\Local\Temp\ipykernel_3756\2011752748.py in ?(input_file, output_file)
#      12         # Reduce PDF size by removing redundant information and compressing data streams
#      13         Optimizer.Optimize(doc)
#      14         doc.Save(output_file, SDFDoc.e_linearized)
#      15         doc.Close()
# ---> 16     except Exception as e:
#      17         print("Error compress_file=", e)
#      18         doc.Close()
#      19         return False
#
# ~\AppData\Roaming\Python\Python311\site-packages\PDFNetPython3\PDFNetPython.py in ?(self, *args)
# > 10905     def Save(self, *args):
#   10906         return _PDFNetPython.PDFDoc_Save(self, *args)
#
# KeyboardInterrupt:
